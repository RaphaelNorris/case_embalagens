# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_raw = pd.read_parquet('../../data/02 - trusted/parquet/tb_paradas.parquet')
df_raw
# Out:
#     CD_PARADA                    TX_DESCRICAO  FL_USADACONVERSAO  \
# 0         245         ENROLOU PAPEL NA PRENSA              False
# 1         246  ENROLOU PAPEL NO ROLO CORRUGAD              False
# 2         247         EXCESSO DE AGUA NA COLA              False
# 3         248                EXCESSO DE FREIO              False
# 4         249               FALHA OPERACIONAL              False
# ..        ...                             ...                ...
# 694     11101                 AVARIA MECÂNICA              False
# 695     11102               BLOQUEIO MECÂNICO              False
# 696     11103                 MANCAL AVARIADO              False
# 697     11104               CORRENTE AVARIADA              False
# 698     11106               QUEBRA DE CORREIA              False
#
#      FL_DESATIVADA  FL_FLAGEXTERNA
# 0            False           False
# 1            False           False
# 2            False           False
# 3            False           False
# ...

# %%
df_raw[df_raw['FL_USADACONVERSAO'] == False]
# Out:
#     CD_PARADA                    TX_DESCRICAO  FL_USADACONVERSAO  \
# 0         245         ENROLOU PAPEL NA PRENSA              False
# 1         246  ENROLOU PAPEL NO ROLO CORRUGAD              False
# 2         247         EXCESSO DE AGUA NA COLA              False
# 3         248                EXCESSO DE FREIO              False
# 4         249               FALHA OPERACIONAL              False
# ..        ...                             ...                ...
# 694     11101                 AVARIA MECÂNICA              False
# 695     11102               BLOQUEIO MECÂNICO              False
# 696     11103                 MANCAL AVARIADO              False
# 697     11104               CORRENTE AVARIADA              False
# 698     11106               QUEBRA DE CORREIA              False
#
#      FL_DESATIVADA  FL_FLAGEXTERNA
# 0            False           False
# 1            False           False
# 2            False           False
# 3            False           False
# ...

# %%
df_raw[df_raw['FL_USADACONVERSAO'] == True]
# Out:
#     CD_PARADA                    TX_DESCRICAO  FL_USADACONVERSAO  \
# 580         1                          AJUSTE               True
# 581       101                      MANUTENÇÃO               True
# 582       102                FALTA DE INSUMOS               True
# 583       103                          CLICHÊ               True
# 584       104                           TINTA               True
# 585       105                           FORMA               True
# 586       106                       QUALIDADE               True
# 587       107                        REFEIÇÃO               True
# 588       108  TESTES NOVOS PRODUTOS/AMOSTRAS               True
# 589       109            FALTA DE PROGRAMAÇÃO               True
# 590       110                  LAVAR TINTEIRO               True
# 591       111    FALTA DE ENERGIA / AR / ÁGUA               True
# 592       112               LIMPEZA DE CLICHÊ               True
# ...

# %%
df_raw.sort_values('CD_PARADA')
# Out:
#     CD_PARADA                    TX_DESCRICAO  FL_USADACONVERSAO  \
# 580         1                          AJUSTE               True
# 581       101                      MANUTENÇÃO               True
# 582       102                FALTA DE INSUMOS               True
# 265     10201                       FALHA PLC              False
# 266     10202                        FALHA PC              False
# ..        ...                             ...                ...
# 261      9806             TOMBAMENTO DE PILHA              False
# 262      9807     ARMAZÉM INTERMEDIÁRIO CHEIO              False
# 263      9808               PROBLEMA MECÂNICO              False
# 264      9809    PROBLEMA ELÉTRICO/ELETRÔNICO              False
# 190    999997  QLIK -PARADA P/ DIVISÃO SETUP               False
#
#      FL_DESATIVADA  FL_FLAGEXTERNA
# 580          False           False
# 581           True           False
# 582          False           False
# 265          False           False
# ...
