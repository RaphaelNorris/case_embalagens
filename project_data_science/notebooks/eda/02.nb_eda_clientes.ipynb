# %%
import pandas as pd

# %%
df = pd.read_parquet('../../data/02 - trusted/parquet/tb_clientes.parquet')

# %%
df[df['IDCLIENTE'] ==9505]
# Out:
#       IDCLIENTE               CLIENTE CODCLIENTE  CODREPRESENTANTE
# 3639       9505  SETA EMBALAGENS LTDA      14255                90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5586 entries, 0 to 5585
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCLIENTE         5586 non-null   int64
#  1   CLIENTE           5586 non-null   object
#  2   CODCLIENTE        5586 non-null   object
#  3   CODREPRESENTANTE  5586 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 174.7+ KB

# %%
df[df.columns] = df[df.columns].astype(str)

# %%
df.to_parquet('../../data/02 - trusted/parquet/tb_clientes.parquet')
