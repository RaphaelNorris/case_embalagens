# %%
import pandas as pd

df_tarefcon =  pd.read_parquet('../../data/02 - trusted/parquet/tb_tarefcon.parquet')

# %%
df_tarefcon = df_tarefcon[sorted(df_tarefcon.columns)]

# %%
df_tarefcon
# Out:
#          CD_CODIGOPARADAOUCONV CD_FACA CD_MAQUINA             CD_OP  \
# 0                          NaN  6111-2        ACB   598850-2/659652
# 1                          NaN  6111-2        ACB   598850-2/659652
# 2                          NaN  6111-2        ACB   598850-2/659652
# 3                          NaN    4756        ACB   598771-1/398692
# 4                        138.0    None        ACB              None
# ...                        ...     ...        ...               ...
# 1604557                    NaN  6844-1       WAR3   717003-6/350001
# 1604558                  130.0    None       WAR3  710976-28/798711
# 1604559                  140.0    None       WAR3  710976-28/798711
# 1604560                  140.0    None       WAR3  710976-28/798711
# 1604561                  140.0    None       WAR3  710976-28/798711
#
#                 CD_OPONDULADA  CD_ORIGEMREGISTRO CD_TURMA DT_DIADATURMA  \
# 0                        None                0.0        C    2022-06-20
# 1                        None                0.0        C    2022-06-21
# 2                        None                0.0        B    2022-06-22
# 3                        None                0.0        B    2022-06-22
# 4                        None                0.0        B    2022-06-22
# ...                       ...                ...      ...           ...
# 1604557  PRD099638/Várias FTs                1.0        C    2025-08-04
# 1604558                  None                1.0        C    2025-08-04
# 1604559                  None                1.0        C    2025-08-04
# 1604560                  None                1.0        C    2025-08-04
# 1604561                  None                1.0        C    2025-08-04
#
#             DT_FIM  DT_INICIO  FL_FLAGPARADA  FL_REPROGRAMACAO  FL_SKIPFEED  \
# 0       2022-06-21 2022-06-20              0               1.0            0
# 1       2022-06-21 2022-06-21              0               1.0            0
# 2       2022-06-22 2022-06-22              0               1.0            0
# 3       2022-06-22 2022-06-22              0               1.0            0
# 4       2022-06-22 2022-06-22              1               NaN            0
# ...            ...        ...            ...               ...          ...
# 1604557 2025-08-05 2025-08-05              0               1.0            0
# 1604558 2025-08-05 2025-08-05              1               NaN            0
# 1604559 2025-08-05 2025-08-05              1               NaN            0
# 1604560 2025-08-05 2025-08-05              1               NaN            0
# 1604561 2025-08-05 2025-08-05              1               NaN            0
#
#          ID_IDCLIENTE ID_ITEM ID_PEDIDO  ID_USUARIO  QT_CHAPASALIMENTADAS  \
# 0              1428.0  659652  598850-2       191.0                 800.0
# 1              1428.0  659652  598850-2       191.0                 700.0
# 2              1428.0  659652  598850-2       630.0                2100.0
# 3              9758.0  398692  598771-1       191.0               14650.0
# 4                 NaN    None      None       191.0                   NaN
# ...               ...     ...       ...         ...                   ...
# 1604557        1774.0  350001  717003-6       445.0                4800.0
# 1604558           NaN    None      None       445.0                   NaN
# 1604559           NaN    None      None       445.0                   NaN
# 1604560           NaN    None      None       445.0                   NaN
# 1604561           NaN    None      None       445.0                   NaN
#
#          QT_QUANTIDADEAJUSTE  QT_QUANTIDADEPRODUZIDA  QT_QUANTIDADEPROGRAMADA  \
# 0                        0.0                   800.0                    800.0
# 1                        0.0                   700.0                    700.0
# 2                        0.0                  2100.0                   2365.0
# 3                        0.0                 14650.0                  15596.0
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 1604557                  0.0                 19200.0                  19200.0
# 1604558                  NaN                     NaN                      NaN
# 1604559                  NaN                     NaN                      NaN
# 1604560                  NaN                     NaN                      NaN
# 1604561                  NaN                     NaN                      NaN
#
#         TX_DESCORIGEMREGISTRO  VL_ARRANJO  VL_DURACAO  VL_DURACAOPREVISTA  \
# 0               Manual padrão         1.0         180              3161.0
# 1               Manual padrão         1.0          60              2338.0
# 2               Manual padrão         1.0          80               572.0
# 3               Manual padrão         1.0         251              3773.0
# 4               Manual padrão         NaN         149                 NaN
# ...                       ...         ...         ...                 ...
# 1604557            Online CLP         4.0          60                98.0
# 1604558            Online CLP         NaN           2                 NaN
# 1604559            Online CLP         NaN           1                 NaN
# 1604560            Online CLP         NaN           2                 NaN
# 1604561            Online CLP         NaN           1                 NaN
#
#          VL_GRAMATURA
# 0               364.0
# 1               364.0
# 2               364.0
# 3               475.0
# 4                 NaN
# ...               ...
# 1604557         416.0
# 1604558           NaN
# 1604559           NaN
# 1604560           NaN
# 1604561           NaN
#
# [1604562 rows x 26 columns]

# %%
pd.set_option('display.max_columns', None)  # Mostra todas as colunas
df_tarefcon.head(1)
# Out:
#   CD_MAQUINA  FL_FLAGPARADA  CD_CODIGOPARADAOUCONV CD_TURMA            CD_OP  \
# 0        ACB              0                    NaN        C  598850-2/659652
#
#   ID_PEDIDO ID_ITEM  FL_REPROGRAMACAO  VL_ARRANJO  VL_GRAMATURA  \
# 0  598850-2  659652               1.0         1.0         364.0
#
#    QT_QUANTIDADEPROGRAMADA  QT_CHAPASALIMENTADAS  QT_QUANTIDADEPRODUZIDA  \
# 0                    800.0                 800.0                   800.0
#
#    QT_QUANTIDADEAJUSTE  VL_DURACAOPREVISTA  DT_INICIO     DT_FIM  \
# 0                  0.0              3161.0 2022-06-20 2022-06-21
#
#   DT_DIADATURMA  ID_IDCLIENTE  ID_USUARIO  CD_ORIGEMREGISTRO  \
# 0    2022-06-20        1428.0       191.0                0.0
#
#   TX_DESCORIGEMREGISTRO  FL_SKIPFEED CD_OPONDULADA  VL_DURACAO CD_FACA
# 0         Manual padrão            0          None         180  6111-2

# %%
# Out:
# Index(['CD_MAQUINA', 'FL_FLAGPARADA', 'CD_CODIGOPARADAOUCONV', 'CD_TURMA',
#        'CD_OP', 'ID_PEDIDO', 'ID_ITEM', 'FL_REPROGRAMACAO', 'VL_ARRANJO',
#        'VL_GRAMATURA', 'QT_QUANTIDADEPROGRAMADA', 'QT_CHAPASALIMENTADAS',
#        'QT_QUANTIDADEPRODUZIDA', 'QT_QUANTIDADEAJUSTE', 'VL_DURACAOPREVISTA',
#        'DT_INICIO', 'DT_FIM', 'DT_DIADATURMA', 'ID_IDCLIENTE', 'ID_USUARIO',
#        'CD_ORIGEMREGISTRO', 'TX_DESCORIGEMREGISTRO', 'FL_SKIPFEED',
#        'CD_OPONDULADA', 'VL_DURACAO', 'CD_FACA'],
#       dtype='object')
