# %%
import pandas as pd
import sys

sys.path.append('./../')
from src.data.conn_oracle import load_env_oracle
import os
import pyarrow

# %%
conn = load_env_oracle()
# Out:
# User: TRIMBOX_RAW
# Host: ORACLE10G
# Port: 1521
# Service: adami.adami.corporativo

# %%
df = pd.read_sql('SELECT  * FROM BALANCA. INSPECAO_LAB', conn)
# Out:
# /tmp/ipykernel_2520566/1335205006.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT  * FROM BALANCA. INSPECAO_LAB', conn)

# %%
df.shape
# Out:
# (879567, 164)

# %%
tamanho_bytes = df.memory_usage(deep=True).sum()

tamanho_gb = tamanho_bytes / (1024**3)

# %%
tamanho_gb
# Out:
# np.float64(1.7082650233060122)

# %%
pip install --upgrade pandas pyarrow fastparquet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 25.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 36.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [fastparquet] [fastparquet]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_parquet("balanca_ingestao_lab_full.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.to_parquet("balanca_ingestao_lab_full.parquet")
#
# File ~/Documentos/raphael-norris-ds/.venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Documentos/raphael-norris-ds/.venv/lib/python3.12/site-packages/pandas/core/frame.py:3118, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3037 """
#    3038 Write a DataFrame to the binary parquet format.
# ...

# %%
(df.isnull().sum()/df.shape[0]*100).sort_values(ascending=False).head(20)
# Out:
# COFCAPA                 100.000000
# COFBASE                 100.000000
# USUMOD_LIB              100.000000
# RCTLTMIN                100.000000
# SCT                      99.991018
# SCTL                     98.668076
# TIPORECLASS              97.667002
# USUACE                   96.729710
# DATACE                   96.729710
# DUREZA                   95.376980
# TEOSOL                   94.644678
# GRAUCURTA                94.566343
# DATAEXPEDIDA             92.637413
# OBS1                     92.144778
# POROSIDADE               91.518325
# DESVIO_TOTAL_GRA         90.174804
# DESVIO_TOTAL_UMIDADE     90.174008
# QUANT_KEMENE             88.678707
# KYMENE                   87.485717
# CMT                      86.058063
# dtype: float64
